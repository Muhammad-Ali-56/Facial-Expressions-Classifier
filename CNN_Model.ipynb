# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Ali-56/Facial/blob/main/CNN_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***CNN Project By Numpy Array***

# %%
#!rm -r "/content/drive/MyDrive/cropped"

# %%
# !ls "/content/drive/MyDrive/"
# Out:
# 'Colab Notebooks'   data   Untitled.ipynb

# %%
!7za -y x "/content/drive/MyDrive/data/image/origin.7z.*"
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 8 files, 8113576419 bytes (7738 MiB)
#   0%
# Extracting archive: /content/drive/MyDrive/data/image/origin.7z.001
# --
# Path = /content/drive/MyDrive/data/image/origin.7z.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 8
# Total Physical Size = 8113576419
# ----
# Path = origin.7z
# Size = 8113576419
# --
# Path = origin.7z
# Type = 7z
# Physical Size = 8113576419
# Headers Size = 863607
# Method = LZMA:25
# Solid = +
# Blocks = 2
#
# Everything is Ok
# 100% 106963
# Folders: 1
# Files: 106962
# Size:       8386671768
# Compressed: 8113576419

# %%
 # !mkdir "/content/drive/MyDrive/Extracted"

# %%
 # !cp -r ./origin "/content/drive/MyDrive/Extracted"

# %%
label_file_path = r"/content/drive/MyDrive/data/label/label.lst"
image_folder_path = r"/content/drive/MyDrive/Extracted/origin"

# %%
import pandas as pd
df_info = pd.read_csv(label_file_path, sep=' ', header=None)
col_names = "image_name face_id_in_image face_box_top face_box_left face_box_right face_box_bottom face_box_cofidence expression_label".split(' ')
df_info.columns = col_names
df_info.head()

# %%
df_info.shape

# %%
for ind in df_info.index:
  df_iterate = df_info['image_name'][ind], df_info['face_box_cofidence'][ind]
print(df_iterate)

# %%
df_sel = df_info[df_info.face_box_cofidence > 40]
df_sel.head()

# %%
df_sel.shape

# %%
df_sel.image_name.value_counts()

# %%
for i, row in df_sel.iterrows():
  image_name = row['image_name']
  x1 = row['face_box_left']
  x2 = row['face_box_right']
  y1 = row['face_box_top']
  y2 = row['face_box_bottom']
  a = [x1,x2, y1,y2]

print(row)

# %%
 # !mkdir "/content/drive/MyDrive/cropped"

# %%
import os
import cv2

source_folder = "/content/drive/MyDrive/Extracted/origin"
destination_folder = "/content/drive/MyDrive/cropped"

# Get a list of all image files in the source folder
image_files = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

# Sort the list of image files to ensure the first 20 files are processed in order
image_files.sort()

# Define the number of images to crop
num_images_to_crop = 20

# Loop through the first 20 image files and crop them
for image_file in image_files[:num_images_to_crop]:
    # Read the source image using OpenCV
    image_path = os.path.join(source_folder, image_file)
    image = cv2.imread(image_path)

    # Define the region of interest (ROI) to crop (example values)
    image_name = row['image_name']
    x1 = row['face_box_left']
    x2 = row['face_box_right']
    y1 = row['face_box_top']
    y2 = row['face_box_bottom']
    xy = row['face_box_cofidence']

    # Crop the image using the defined ROI
    cropped_image = image[y1:y2, x1:x2]

    # Save the cropped image to the destination folder
    cropped_image_filename = "cropped_" + image_file  # You can give any desired filename
    cropped_image_path = os.path.join(destination_folder, cropped_image_filename)
    cv2.imwrite(cropped_image_path,cropped_image)

# %%
import cv2

image_path = '/content/drive/MyDrive/cropped/cropped_Roller_Coaster_lady_862.jpg'


# Attempt to read the image
image = cv2.imread(image_path)

# Check if the image is loaded successfully
if image is not None:
    print("Image loaded successfully.")
else:
    print("Failed to load the image.")

# %%
import matplotlib.pyplot as plt

image = plt.imread('/content/drive/MyDrive/cropped/cropped_Roller_Coaster_lady_862.jpg')
plt.imshow(image)
plt.axis('on')
plt.show

# %%
import os
import cv2
from tqdm import tqdm_gui

X = []
Y = []

image_directory = '/content/drive/MyDrive/Extracted/origin'
cropped_directory = '/content/drive/MyDrive/cropped'

for i, row in df_sel.sample(9000).iterrows():
    image_name = row['image_name']
    x1 = row['face_box_left']
    x2 = row['face_box_right']
    y1 = row['face_box_top']
    y2 = row['face_box_bottom']
    label = row['expression_label']

    cropped_path = os.path.join(cropped_directory, f"cropped_{image_name}")

    # Read the cropped image
    comb_path = os.path.join(image_directory, image_name)
    cropped_image = cv2.imread(comb_path)

    if cropped_image is not None:
        face = cropped_image[x1:x2, y1:y2]

        # Debugging: Print face shape and cropping coordinates
        print(f"Face shape: {face.shape}, x1={x1}, x2={x2}, y1={y1}, y2={y2}")
    else:
        continue

    if face is not None and not face.size == 0:
        face_resized = cv2.resize(face, (64, 64))
    else:
        continue

    X.append(face_resized)
    Y.append(label)

# %%
print(len(X))
print(len(Y))

# %%
import numpy as np
X = np.array(X)
Y = np.array(Y)

# %%
print(len(X))

# %%
if isinstance(X, np.ndarray) and isinstance(Y, np.ndarray):
    print("Images are converted to NumPy arrays.")
else:
    print("Images are not converted to NumPy arrays.")

# %%
X_normalized = X.astype('float32') / 255.0

# Check the shape of the array
print("Shape of X_normalized:", X_normalized.shape)

# %%
if np.min(X_normalized) >= 0.0 and np.max(X_normalized) <= 1.0:
    print("Images are properly normalized.")
else:
    print("Images are not properly normalized. Pixel value range: [", np.min(X_normalized), ",", np.max(X_normalized), "]")

# %%
#reshaping images for oversamlping
X_new = X.reshape(-1, 64*64*3)

# %%
# oversampling the images

from imblearn.over_sampling import SMOTE

sampler = SMOTE()

XSMOTE, YSMOTE = sampler.fit_resample(X_new, Y)

# %%
pd.Series(YSMOTE).value_counts()

# %%
# again bringing images to its original shape
X = XSMOTE.reshape(-1, 64, 64, 3)

# %%
#  label encoding, OneHotEncoder
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(Y)
onehot_encoder = OneHotEncoder(sparse=False)
onehot_encoded = onehot_encoder.fit_transform(integer_encoded.reshape(-1, 1))

# Check the shape of onehot_encoded
print("Shape of onehot_encoded:", onehot_encoded.shape)

# %%
# Check the first few rows of onehot_encoded
print("First few rows of onehot_encoded:")
print(onehot_encoded[:5])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale = 1.0/255,
    rotation_range = 20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True
)

datagen.fit(X)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.utils import to_categorical

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_normalized, onehot_encoded, test_size=0.2, random_state=42)

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(onehot_encoded.shape[1], activation='softmax'))  # Use the number of classes from onehot_encoded

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# Train the model
batch_size = 25
epochs = 50
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test loss: {loss:.4f}, Test accuracy: {accuracy:.4f}")
